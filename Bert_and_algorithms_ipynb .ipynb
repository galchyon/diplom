# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import torch
import transformers as ppb
import warnings
warnings.filterwarnings('ignore')

import re
from tqdm import tqdm
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import torch

import itertools
import string

import numpy as np

from IPython.display import clear_output
from matplotlib import pyplot as plt
from nltk.tokenize import WordPunctTokenizer

from sklearn.manifold import TSNE
import plotly.express as px

import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
russian_stopwords = stopwords.words("russian")

from sklearn.model_selection import train_test_split

from sklearn.pipeline import Pipeline

from sklearn.linear_model import SGDClassifier

from sklearn import metrics

from sklearn.ensemble import RandomForestClassifier
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('//content/drive/MyDrive/df_difficult_26_01.csv')
df
# Out:
#                                                 doc_name  \
# 0      Распоряжение, федеральный уровень, глава испол...
# 1      Распоряжение, федеральный уровень, глава испол...
# 2      Указ, федеральный уровень, глава исполнительно...
# 3      Распоряжение, федеральный уровень, глава испол...
# 4      Распоряжение, федеральный уровень, глава испол...
# ...                                                  ...
# 22886  Указ, региональный уровень, глава исполнительн...
# 22887  Указ, региональный уровень, глава исполнительн...
# 22888  Указ, региональный уровень, глава исполнительн...
# 22889  Указ, региональный уровень, глава исполнительн...
# 22890  Указ, региональный уровень, глава исполнительн...
#
#                                                 doc_text  \
# 0      распоряжение президента российской федерации о...
# 1      распоряжение президента российской федерации о...
# 2      указ президента российской федерации об освобо...
# 3      распоряжение президента российской федерации о...
# 4      распоряжение президента российской федерации о...
# ...                                                  ...
# 22886  губернатор орловской области у к аз о мерах по...
# 22887  ммжхжчмитжкъщ  а  г х м  башкортостан республи...
# 22888  у к а з губернатора пермского края   об отмене...
# 22889  у к а з губернатора пермского края   г об утве...
# 22890  указ об отмене ограничительных мероприятий кар...
#
#                                               text_token  \
# 0      распоряжение президент российский федерация ус...
# 1      распоряжение президент российский федерация пр...
# 2      указ президент российский федерация освобожден...
# 3      распоряжение президент российский федерация по...
# 4      распоряжение президент российский федерация по...
# ...                                                  ...
# 22886  губернатор орловский область мера проведение к...
# 22887  ммжхжчмитжкъщий башкортостан республикаь респу...
# 22888  губернатор пермский край отмена ограничение ка...
# 22889  губернатор пермский край утверждение порядок п...
# 22890  указ отмена ограничительный мероприятие карант...
#
#                                       text_token_filtred  \
# 0      распоряжение президент российский федерация ус...
# 1      распоряжение президент российский федерация пр...
# 2      указ президент российский федерация освобожден...
# 3      распоряжение президент российский федерация по...
# 4      распоряжение президент российский федерация по...
# ...                                                  ...
# 22886  губернатор орловский область мера проведение к...
# 22887  ммжхжчмитжкъщий башкортостан республикаь респу...
# 22888  губернатор пермский край отмена ограничение ка...
# 22889  губернатор пермский край утверждение порядок п...
# 22890  указ отмена ограничительный мероприятие карант...
#
#                                           text_difficult
# 0      комитет российский федерация установить числен...
# 1      российский федерация контроль оборот наркотик ...
# 2      федерация контроль оборот наркотик освободить ...
# 3      многолетний плодотворный деятельность наградит...
# 4      молодёжь объявить благодарность андропов игорь...
# ...                                                  ...
# 22886  проживать инвалид ветеран великий отечественны...
# 22887  должность заместитель премьер министр правител...
# 22888  посёлок октябрьский соответствие закон российс...
# 22889  должность пермский край отдельный должность го...
# 22890  область соответствие закон российский федераши...
#
# [22891 rows x 5 columns]

# %%
def get_difficult(text):
  return text[100:-100]

df['text_dif_bert'] = df['doc_text'].apply(get_difficult)

# %%
model_class, tokenizer_class, pretrained_weights = (ppb.DistilBertModel, ppb.DistilBertTokenizer, 'distilbert-base-uncased')

tokenizer = tokenizer_class.from_pretrained(pretrained_weights)
model = model_class.from_pretrained(pretrained_weights)
# Out:
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]

# %%
tokenized_texts = df['doc_text'].apply(lambda x: tokenizer.encode(x, add_special_tokens=True, max_length=512, truncation=True)).values

max_len = max(len(text) for text in tokenized_texts)
padded_texts = torch.tensor([text + [0] * (max_len - len(text)) for text in tokenized_texts])

attention_mask = torch.where(padded_texts > 0, 1, 0)

# %%
tokenized_texts_dif = df['text_dif_bert'].apply(lambda x: tokenizer.encode(x, add_special_tokens=True, max_length=512, truncation=True)).values

max_len = max(len(text) for text in tokenized_texts_dif)
padded_texts_dif = torch.tensor([text + [0] * (max_len - len(text)) for text in tokenized_texts_dif])

attention_mask_dif = torch.where(padded_texts_dif > 0, 1, 0)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
model = model_class.from_pretrained(pretrained_weights)
model.to(device)
batch_size = 16
features = []
with torch.no_grad():
    for i in range(0, len(padded_texts), batch_size):
        texts_batch = padded_texts[i : i + batch_size].to(device)
        mask_batch = attention_mask[i : i + batch_size].to(device)
        output = model(texts_batch, mask_batch)
        batch_features = output.last_hidden_state[:, 0, :].cpu().numpy()
        features.append(batch_features)

features = np.concatenate(features, axis=0)
features.shape
# Out:
# (22891, 768)

# %%
model = model_class.from_pretrained(pretrained_weights)
model.to(device)
batch_size = 16
features_dif = []
with torch.no_grad():
    for i in range(0, len(padded_texts), batch_size):
        texts_batch_dif = padded_texts_dif[i : i + batch_size].to(device)
        mask_batch_dif = attention_mask_dif[i : i + batch_size].to(device)
        output_dif = model(texts_batch_dif, mask_batch_dif)
        batch_features_dif = output_dif.last_hidden_state[:, 0, :].cpu().numpy()
        features_dif.append(batch_features_dif)

features_dif = np.concatenate(features_dif, axis=0)
features_dif.shape
# Out:
# (22891, 768)

# %%
labels = df['doc_name'].values

X_train, X_test, y_train, y_test = train_test_split(features, labels,  test_size=0.2, random_state=42)

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300, init='random')
tsne_results = tsne.fit_transform(X_train[:1500])
fig = px.scatter(
    tsne_results, x=0, y=1,
    color=y_train[:1500], labels={'color': 'Вид НПА'}
)
fig.show()
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 1500 samples in 0.007s...
# [t-SNE] Computed neighbors for 1500 samples in 1.011s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1500
# [t-SNE] Computed conditional probabilities for sample 1500 / 1500
# [t-SNE] Mean sigma: 0.267574
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 69.666016
# [t-SNE] KL divergence after 300 iterations: 1.601602
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e31c8d01-8db5-462d-8f79-02828fb86bbb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e31c8d01-8db5-462d-8f79-02828fb86bbb")) {                    Plotly.newPlot(                        "e31c8d01-8db5-462d-8f79-02828fb86bbb",                        [{"hovertemplate":"\u0412\u0438\u0434 \u041d\u041f\u0410=\u041f\u043e\u0441\u0442\u0430\u043d\u043e\u0432\u043b\u0435\u043d\u0438\u0435, \u0440\u0435\u0433\u0438\u043e\u043d\u0430\u043b\u044c\u043d\u044b\u0439 \u0443\u0440\u043e\u0432\u0435\u043d\u044c, \u0433\u043b\u0430\u0432\u0430 \u0438\u0441\u043f\u043e\u043b\u043d\u0438\u0442\u0435\u043b\u044c\u043d\u043e\u0439 \u0432\u043b\u0430\u0441\u0442\u0438\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u041f\u043e\u0441\u0442\u0430\u043d\u043e\u0432\u043b\u0435\u043d\u0438\u0435, \u0440\u0435\u0433\u0438\u043e\u043d\u0430\u043b\u044c\u043d\u044b\u0439 \u0443\u0440\u043e\u0432\u0435\u043d\u044c, \u0433\u043b\u0430\u0432\u0430 \u0438\u0441\u043f\u043e\u043b\u043d\u0438\u0442\u0435\u043b\u044c\u043d\u043e\u0439 \u0432\u043b\u0430\u0441\u0442\u0438","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"\u041f\u043e\u0441\u0442\u0430\u043d\u043e\u0432\u043b\u0435\u043d\u0438\u0435, \u0440\u0435\u0433\u0438\u043e\u043d\u0430\u043b\u044c\u043d\u044b\u0439 \u0443\u0440\u043e\u0432\u0435\u043d\u044c, \u0433\u043b\u0430\u0432\u0430 \u0438\u0441\u043f\u043e\u043b\u043d\u0438\u0442\u0435\u043b\u044c\u043d\u043e\u0439 \u0432\u043b\u0430\u0441\u0442\u0438","showlegend":true,"x":[-0.7187738418579102,-2.535080909729004,-7.5025224685668945,-2.4882025718688965,-1.8260747194290161,-4.726547718048096,-7.503909111022949,-3.309802770614624,-2.2563514709472656,-1.0672624111175537,-0.8199442625045776,-6.720606327056885,-5.764480113983154,-0.8810570240020752,-1.4203892946243286,-0.23767325282096863,-3.3155980110168457,-0.1920517534017563,-1.3972651958465576,-1.1338385343551636,-8.046659469604492,-1.948663353919983,-1.3923407793045044,-4.587578773498535,-7.269781112670898,-5.936901569366455,-3.6056911945343018,1.9843484163284302,-4.877457618713379,-4.69236421585083,-1.0332396030426025,-0.7503874897956848,-1.0267242193222046,-2.8040900230407715,-2.203082799911499,-0.9288897514343262,-0.359446257352829,-4.821364879608154,-4.505870342254639,-4.752695560455322,-3.6391096115112305,-0.42906972765922546,-0.7049479484558105,-4.2210693359375,-0.33288004994392395,-3.720945358276367,-2.3921289443969727,-3.542752504348755,-3.7434937953948975,-3.271310806274414,-1.0034528970718384,-1.068848967552185,-0.5499516725540161,-6.580305576324463,-2.5055341720581055,-4.407382488250732,-3.986440896987915,-3.32379412651062,-1.5568724870681763,-0.32560357451438904,-2.657335042953491,-2.9043209552764893,-3.170896053314209,-0.7635206580162048,-4.3698506355285645,-0.7428839802742004,-2.780927896499634,-4.844753265380859,-2.2859463691711426,-3.317516565322876,-3.483116388320923,-2.3697094917297363,-7.859408378601074,-2.8249988555908203,-3.419271469116211,-1.8695958852767944,-2.795344352722168,-0.7264010310173035,-0.4867425560951233,-2.445335865020752,-1.0357942581176758,-8.969051361083984,-7.94119119644165,-2.164644479751587,-5.32963228225708,-8.94258975982666,-0.5772033333778381,-0.378574937582016,-0.6852268576622009,-1.360037088394165,-0.7885640263557434,-0.7805638313293457,-1.323125958442688,-4.317252159118652,-1.7527360916137695,-7.840790271759033,-4.732646942138672,-8.464461326599121,9.962190628051758,-9.196473121643066,-4.763886451721191,-0.9174201488494873,-0.287078857421875,-1.7674169540405273,-8.507063865661621,-2.5128841400146484,-3.1314830780029297,-0.1829996258020401],"xaxis":"x","y":[0.2159704267978668 ...

# %%
def print_metrics(test, preds):
  print(metrics.classification_report(test, preds))
  print(metrics.accuracy_score(test, preds), 'accuracy')
  print(metrics.precision_score(test, preds, average='macro'), 'precision')
  print(metrics.recall_score(test, preds, average='macro'), 'recall')
  print(metrics.f1_score(test, preds, average='macro'), 'f1')

# %%
lr_ppl_clf = Pipeline([

    ('lr_clf', LogisticRegression(random_state=42))
])

parameters = {
              'lr_clf__solver':['lbfgs', 'newton-cg', 'sag', 'saga'],
              'lr_clf__class_weight':[None, 'balanced'],
              'lr_clf__penalty':[None, 'l2', 'l1', 'elasticnet']
              }
model = GridSearchCV(lr_ppl_clf, parameters, cv=4, n_jobs=-1).fit(X_train[:1000], y_train[:1000])
print('Best score and parameter combination:')
print(model.best_score_, model.best_params_)
# Out:
# Best score and parameter combination:
# 0.913 {'lr_clf__class_weight': None, 'lr_clf__penalty': None, 'lr_clf__solver': 'newton-cg'}

# %%
lr_ppl_clf = Pipeline([

    ('lr_clf', LogisticRegression(solver='newton-cg',penalty=None, class_weight=None, random_state=42))
])
lr_ppl_clf.fit(X_train, y_train)
predicted_lr_val = lr_ppl_clf.predict(X_test)
print_metrics(y_test, predicted_lr_val)
# Out:
#                                                                    precision    recall  f1-score   support
#
#                Закон, региональный уровень, законодательный орган       1.00      0.99      0.99       329
#                 Закон, федеральный уровень, законодательный орган       1.00      1.00      1.00       347
#  Постановление, региональный уровень, глава исполнительной власти       0.98      0.98      0.98       318
#        Постановление, региональный уровень, законодательный орган       0.98      0.98      0.98       302
# Постановление, региональный уровень, органы исполнительной власти       1.00      0.98      0.99       244
#                Постановление, региональный уровень, правительство       0.97      0.97      0.97       318
#                 Постановление, федеральный уровень, правительство       1.00      1.00      1.00       314
#        Приказ, региональный уровень, органы исполнительной власти       0.97      0.98      0.98       325
#         Приказ, федеральный уровень, органы исполнительной власти       0.98      0.97      0.98       315
#   Распоряжение, региональный уровень, глава исполнительной власти       0.98      0.98      0.98       330
#                 Распоряжение, региональный уровень, правительство       0.98      0.98      0.98       323
#    Распоряжение, федеральный уровень, глава исполнительной власти       0.99      1.00      1.00       272
#                  Распоряжение, федеральный уровень, правительство       1.00      1.00      1.00       324
#           Указ, региональный уровень, глава исполнительной власти       0.98      0.99      0.99       296
#            Указ, федеральный уровень, глава исполнительной власти       1.00      1.00      1.00       222
#
#                                                          accuracy                           0.99      4579
#                                                         macro avg       0.99      0.99      0.99      4579
#                                                      weighted avg       0.99      0.99      0.99      4579
#
# 0.9868967023367547 accuracy
# 0.9873255642251799 precision
# 0.9870284761283028 recall
# 0.9871575664648126 f1

# %%
sgd_ppl_clf = Pipeline([

    ('sgd_clf', SGDClassifier(random_state=42))
])

parameters = {
              'sgd_clf__loss':['hinge', 'log', 'modified_huber', 'squared_hinge', 'perceptron'],
              'sgd_clf__class_weight':[None, 'balanced'],
              'sgd_clf__penalty':[None, 'l2', 'l1', 'elasticnet']
              }
model = GridSearchCV(sgd_ppl_clf, parameters, cv=4, n_jobs=-1).fit(X_train[:1000], y_train[:1000])
print('Best score and parameter combination:')
print(model.best_score_, model.best_params_)
# Out:
# Best score and parameter combination:
# 0.744 {'sgd_clf__class_weight': None, 'sgd_clf__loss': 'log', 'sgd_clf__penalty': None}

# %%
sgd_ppl_clf = Pipeline([

    ('sgd_clf', SGDClassifier(loss='log',penalty=None, class_weight=None, random_state=42))
])
sgd_ppl_clf.fit(X_train, y_train)


predicted_sgd_val = sgd_ppl_clf.predict(X_test)
print_metrics(y_test, predicted_sgd_val)
# Out:
#                                                                    precision    recall  f1-score   support
#
#                Закон, региональный уровень, законодательный орган       0.94      0.94      0.94       329
#                 Закон, федеральный уровень, законодательный орган       0.97      0.99      0.98       347
#  Постановление, региональный уровень, глава исполнительной власти       0.90      0.88      0.89       318
#        Постановление, региональный уровень, законодательный орган       0.95      0.91      0.93       302
# Постановление, региональный уровень, органы исполнительной власти       0.96      0.87      0.91       244
#                Постановление, региональный уровень, правительство       0.81      0.82      0.82       318
#                 Постановление, федеральный уровень, правительство       0.96      0.93      0.95       314
#        Приказ, региональный уровень, органы исполнительной власти       0.84      0.92      0.88       325
#         Приказ, федеральный уровень, органы исполнительной власти       0.91      0.94      0.93       315
#   Распоряжение, региональный уровень, глава исполнительной власти       0.90      0.97      0.94       330
#                 Распоряжение, региональный уровень, правительство       0.87      0.89      0.88       323
#    Распоряжение, федеральный уровень, глава исполнительной власти       0.98      0.96      0.97       272
#                  Распоряжение, федеральный уровень, правительство       0.99      0.96      0.97       324
#           Указ, региональный уровень, глава исполнительной власти       0.93      0.88      0.90       296
#            Указ, федеральный уровень, глава исполнительной власти       0.98      0.97      0.98       222
#
#                                                          accuracy                           0.92      4579
#                                                         macro avg       0.93      0.92      0.92      4579
#                                                      weighted avg       0.92      0.92      0.92      4579
#
# 0.9218169906093033 accuracy
# 0.9253301958968033 precision
# 0.9216950592903772 recall
# 0.9230468546352816 f1

# %%
fr_ppl_clf = Pipeline([

    ('rf_clf', RandomForestClassifier(random_state=42))
])

parameters = {
              'rf_clf__n_estimators':[ 300, 500, 700],
              'rf_clf__max_depth':[ 5, 8, 11, 14],
              'rf_clf__criterion':['gini', 'entropy', 'log_loss']
              }
model = GridSearchCV(fr_ppl_clf, parameters, cv=4, n_jobs=-1).fit(X_train[:1000], y_train[:1000])
print('Best score and parameter combination:')
print(model.best_score_, model.best_params_)

# %%
fr_ppl_clf = Pipeline([

    ('sgd_clf', RandomForestClassifier(n_estimators=500,max_depth=14, criterion='gini', random_state=42))
])
fr_ppl_clf.fit(X_train, y_train)


ppredicted_fr_val = fr_ppl_clf.predict(X_test)
print_metrics(y_test, ppredicted_fr_val)
# Out:
#                                                                    precision    recall  f1-score   support
#
#                Закон, региональный уровень, законодательный орган       0.96      0.96      0.96       329
#                 Закон, федеральный уровень, законодательный орган       0.99      1.00      0.99       347
#  Постановление, региональный уровень, глава исполнительной власти       0.92      0.88      0.90       318
#        Постановление, региональный уровень, законодательный орган       0.97      0.95      0.96       302
# Постановление, региональный уровень, органы исполнительной власти       1.00      0.92      0.96       244
#                Постановление, региональный уровень, правительство       0.89      0.82      0.86       318
#                 Постановление, федеральный уровень, правительство       0.98      0.98      0.98       314
#        Приказ, региональный уровень, органы исполнительной власти       0.88      0.92      0.90       325
#         Приказ, федеральный уровень, органы исполнительной власти       0.91      0.97      0.94       315
#   Распоряжение, региональный уровень, глава исполнительной власти       0.95      0.94      0.94       330
#                 Распоряжение, региональный уровень, правительство       0.86      0.93      0.89       323
#    Распоряжение, федеральный уровень, глава исполнительной власти       0.98      1.00      0.99       272
#                  Распоряжение, федеральный уровень, правительство       0.99      0.99      0.99       324
#           Указ, региональный уровень, глава исполнительной власти       0.91      0.93      0.92       296
#            Указ, федеральный уровень, глава исполнительной власти       1.00      1.00      1.00       222
#
#                                                          accuracy                           0.94      4579
#                                                         macro avg       0.95      0.94      0.95      4579
#                                                      weighted avg       0.94      0.94      0.94      4579
#
# 0.9438742083424329 accuracy
# 0.9467219165557962 precision
# 0.9446448280016775 recall
# 0.9452302292508745 f1

# %% [markdown]
# Вывод: использование BERT перед подачей классификатору повышает точность результата.
# Также можно предположить, что релевантная для классификации информация содержится в начале текста - что неудивительно, т к это соответствует реальной структуре юридического документа

# %%
X_train, X_test, y_train, y_test = train_test_split(features_dif, labels,  test_size=0.2, random_state=42)
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300, init='random')
tsne_results = tsne.fit_transform(X_train[:1500])
fig = px.scatter(
    tsne_results, x=0, y=1,
    color=y_train[:1500], labels={'color': 'Вид НПА'}
)
fig.show()
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 1500 samples in 0.002s...
# [t-SNE] Computed neighbors for 1500 samples in 0.515s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1500
# [t-SNE] Computed conditional probabilities for sample 1500 / 1500
# [t-SNE] Mean sigma: 0.261465
# [t-SNE] KL divergence after 100 iterations with early exaggeration: 69.971519
# [t-SNE] KL divergence after 300 iterations: 1.753632
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ae61d984-e9c9-4331-9c02-dd73eabe4195" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae61d984-e9c9-4331-9c02-dd73eabe4195")) {                    Plotly.newPlot(                        "ae61d984-e9c9-4331-9c02-dd73eabe4195",                        [{"hovertemplate":"\u0412\u0438\u0434 \u041d\u041f\u0410=\u041f\u043e\u0441\u0442\u0430\u043d\u043e\u0432\u043b\u0435\u043d\u0438\u0435, \u0440\u0435\u0433\u0438\u043e\u043d\u0430\u043b\u044c\u043d\u044b\u0439 \u0443\u0440\u043e\u0432\u0435\u043d\u044c, \u0433\u043b\u0430\u0432\u0430 \u0438\u0441\u043f\u043e\u043b\u043d\u0438\u0442\u0435\u043b\u044c\u043d\u043e\u0439 \u0432\u043b\u0430\u0441\u0442\u0438\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u041f\u043e\u0441\u0442\u0430\u043d\u043e\u0432\u043b\u0435\u043d\u0438\u0435, \u0440\u0435\u0433\u0438\u043e\u043d\u0430\u043b\u044c\u043d\u044b\u0439 \u0443\u0440\u043e\u0432\u0435\u043d\u044c, \u0433\u043b\u0430\u0432\u0430 \u0438\u0441\u043f\u043e\u043b\u043d\u0438\u0442\u0435\u043b\u044c\u043d\u043e\u0439 \u0432\u043b\u0430\u0441\u0442\u0438","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"\u041f\u043e\u0441\u0442\u0430\u043d\u043e\u0432\u043b\u0435\u043d\u0438\u0435, \u0440\u0435\u0433\u0438\u043e\u043d\u0430\u043b\u044c\u043d\u044b\u0439 \u0443\u0440\u043e\u0432\u0435\u043d\u044c, \u0433\u043b\u0430\u0432\u0430 \u0438\u0441\u043f\u043e\u043b\u043d\u0438\u0442\u0435\u043b\u044c\u043d\u043e\u0439 \u0432\u043b\u0430\u0441\u0442\u0438","showlegend":true,"x":[-0.7145401239395142,11.29308795928955,-9.058106422424316,-1.917543888092041,1.226326823234558,-7.893470764160156,-12.42663860321045,1.973465085029602,-2.675499200820923,3.1734933853149414,-1.4790230989456177,-1.3902634382247925,6.214285373687744,-5.843451499938965,-0.767693817615509,-1.0040950775146484,2.006512403488159,2.9528162479400635,-2.128190279006958,-2.975597858428955,-1.7113409042358398,0.1823032647371292,-1.2932602167129517,-7.439460277557373,-1.6919409036636353,6.168255805969238,-9.512430191040039,-11.31433391571045,1.6347320079803467,-7.401299476623535,-2.817112922668457,-5.748096466064453,-5.4151811599731445,-1.9633269309997559,-2.3595378398895264,2.2488577365875244,-1.4377816915512085,-4.002613067626953,-6.919429779052734,4.2229719161987305,0.679061233997345,-3.5652735233306885,1.532533049583435,-11.875589370727539,-7.368169784545898,-10.982368469238281,2.8445401191711426,0.2832310199737549,-0.7546705603599548,0.5079617500305176,-3.8035640716552734,1.0724586248397827,-3.528696060180664,1.740523338317871,1.4471631050109863,-11.94992446899414,4.938894748687744,0.6580770015716553,13.356274604797363,12.861183166503906,1.7274855375289917,5.92834997177124,0.17948150634765625,-2.3501932621002197,-2.308140516281128,3.725862503051758,5.851668834686279,-7.8421854972839355,-0.9120878577232361,-10.78773021697998,3.6519808769226074,-1.8357981443405151,-0.7637423276901245,-3.474982738494873,1.4748896360397339,-3.730942487716675,0.3035348057746887,2.3713316917419434,7.469210624694824,2.8849360942840576,5.627683639526367,1.1925840377807617,-3.0121560096740723,13.042954444885254,9.06700611114502,1.156562089920044,-0.3509977161884308,-4.441760540008545,4.6428070068359375,-8.440074920654297,4.694003582000732,5.100840091705322,6.506444931030273,-1.2677406072616577,-2.0089426040649414,-1.1180692911148071,-7.609121799468994,-2.3503949642181396,1.918228268623352,1.1220204830169678,-11.031828880310059,3.812293767929077,5.971320629119873,-5.318129062652588,-4.799614906311035,5.8772125244140625,-4.151876449584961,-2.1509997844696045],"xaxis":"x","y":[-11.485755920410156,-9.4586181640625,-16.143701553344727,0.543 ...

# %%
lr_ppl_clf = Pipeline([

    ('lr_clf', LogisticRegression(random_state=42))
])

parameters = {
              'lr_clf__solver':['lbfgs', 'newton-cg', 'sag', 'saga'],
              'lr_clf__class_weight':[None, 'balanced'],
              'lr_clf__penalty':[None, 'l2', 'l1', 'elasticnet']
              }
model = GridSearchCV(lr_ppl_clf, parameters, cv=4, n_jobs=-1).fit(X_train[:1000], y_train[:1000])
print('Best score and parameter combination:')
print(model.best_score_, model.best_params_)
# Out:
# Best score and parameter combination:
# 0.54 {'lr_clf__class_weight': 'balanced', 'lr_clf__penalty': None, 'lr_clf__solver': 'newton-cg'}

# %%
lr_ppl_clf = Pipeline([

    ('lr_clf', LogisticRegression(solver='newton-cg',penalty=None, class_weight='balanced', random_state=42))
])
lr_ppl_clf.fit(X_train, y_train)
predicted_lr_val = lr_ppl_clf.predict(X_test)
print_metrics(y_test, predicted_lr_val)
# Out:
#                                                                    precision    recall  f1-score   support
#
#                Закон, региональный уровень, законодательный орган       0.89      0.90      0.90       329
#                 Закон, федеральный уровень, законодательный орган       0.98      0.98      0.98       347
#  Постановление, региональный уровень, глава исполнительной власти       0.77      0.75      0.76       318
#        Постановление, региональный уровень, законодательный орган       0.85      0.83      0.84       302
# Постановление, региональный уровень, органы исполнительной власти       0.89      0.90      0.89       244
#                Постановление, региональный уровень, правительство       0.71      0.73      0.72       318
#                 Постановление, федеральный уровень, правительство       0.91      0.89      0.90       314
#        Приказ, региональный уровень, органы исполнительной власти       0.81      0.82      0.82       325
#         Приказ, федеральный уровень, органы исполнительной власти       0.88      0.85      0.87       315
#   Распоряжение, региональный уровень, глава исполнительной власти       0.75      0.76      0.75       330
#                 Распоряжение, региональный уровень, правительство       0.73      0.70      0.72       323
#    Распоряжение, федеральный уровень, глава исполнительной власти       0.82      0.84      0.83       272
#                  Распоряжение, федеральный уровень, правительство       0.87      0.87      0.87       324
#           Указ, региональный уровень, глава исполнительной власти       0.69      0.73      0.71       296
#            Указ, федеральный уровень, глава исполнительной власти       0.82      0.82      0.82       222
#
#                                                          accuracy                           0.82      4579
#                                                         macro avg       0.83      0.82      0.82      4579
#                                                      weighted avg       0.83      0.82      0.83      4579
#
# 0.8248525879012885 accuracy
# 0.8250651874698189 precision
# 0.824830792969837 recall
# 0.8247991724741696 f1

# %%
sgd_ppl_clf = Pipeline([

    ('sgd_clf', SGDClassifier(random_state=42))
])

parameters = {
              'sgd_clf__loss':['hinge', 'log', 'modified_huber', 'squared_hinge', 'perceptron'],
              'sgd_clf__class_weight':[None, 'balanced'],
              'sgd_clf__penalty':[None, 'l2', 'l1', 'elasticnet']
              }
model = GridSearchCV(sgd_ppl_clf, parameters, cv=4, n_jobs=-1).fit(X_train[:1000], y_train[:1000])
print('Best score and parameter combination:')
print(model.best_score_, model.best_params_)
# Out:
# Best score and parameter combination:
# 0.39499999999999996 {'sgd_clf__class_weight': 'balanced', 'sgd_clf__loss': 'modified_huber', 'sgd_clf__penalty': None}

# %%
sgd_ppl_clf = Pipeline([

    ('sgd_clf', SGDClassifier(loss='modified_huber',penalty=None, class_weight='balanced', random_state=42))
])
sgd_ppl_clf.fit(X_train, y_train)


predicted_sgd_val = sgd_ppl_clf.predict(X_test)
print_metrics(y_test, predicted_sgd_val)
# Out:
#                                                                    precision    recall  f1-score   support
#
#                Закон, региональный уровень, законодательный орган       0.86      0.81      0.84       329
#                 Закон, федеральный уровень, законодательный орган       0.93      0.91      0.92       347
#  Постановление, региональный уровень, глава исполнительной власти       0.59      0.61      0.60       318
#        Постановление, региональный уровень, законодательный орган       0.79      0.73      0.76       302
# Постановление, региональный уровень, органы исполнительной власти       0.81      0.83      0.82       244
#                Постановление, региональный уровень, правительство       0.59      0.59      0.59       318
#                 Постановление, федеральный уровень, правительство       0.80      0.74      0.77       314
#        Приказ, региональный уровень, органы исполнительной власти       0.77      0.66      0.71       325
#         Приказ, федеральный уровень, органы исполнительной власти       0.74      0.76      0.75       315
#   Распоряжение, региональный уровень, глава исполнительной власти       0.68      0.64      0.66       330
#                 Распоряжение, региональный уровень, правительство       0.45      0.67      0.54       323
#    Распоряжение, федеральный уровень, глава исполнительной власти       0.72      0.59      0.65       272
#                  Распоряжение, федеральный уровень, правительство       0.74      0.68      0.71       324
#           Указ, региональный уровень, глава исполнительной власти       0.55      0.56      0.56       296
#            Указ, федеральный уровень, глава исполнительной власти       0.53      0.61      0.57       222
#
#                                                          accuracy                           0.69      4579
#                                                         macro avg       0.70      0.69      0.70      4579
#                                                      weighted avg       0.71      0.69      0.70      4579
#
# 0.6942563878576108 accuracy
# 0.7037888075777787 precision
# 0.6919543927334416 recall
# 0.695190037570749 f1

# %%
fr_ppl_clf = Pipeline([

    ('rf_clf', RandomForestClassifier(random_state=42))
])

parameters = {
              'rf_clf__n_estimators':[ 300, 500, 700],
              'rf_clf__max_depth':[ 5, 8, 11, 14],
              'rf_clf__criterion':['gini', 'entropy', 'log_loss']
              }
model = GridSearchCV(fr_ppl_clf, parameters, cv=4, n_jobs=-1).fit(X_train[:1000], y_train[:1000])
print('Best score and parameter combination:')
print(model.best_score_, model.best_params_)

# %%
fr_ppl_clf = Pipeline([

    ('sgd_clf', RandomForestClassifier(n_estimators=300,max_depth=14, criterion='gini', random_state=42))
])
fr_ppl_clf.fit(X_train, y_train)


ppredicted_fr_val = fr_ppl_clf.predict(X_test)
print_metrics(y_test, ppredicted_fr_val)
# Out:
#                                                                    precision    recall  f1-score   support
#
#                Закон, региональный уровень, законодательный орган       0.71      0.78      0.74       329
#                 Закон, федеральный уровень, законодательный орган       0.91      0.90      0.91       347
#  Постановление, региональный уровень, глава исполнительной власти       0.63      0.66      0.64       318
#        Постановление, региональный уровень, законодательный орган       0.77      0.71      0.74       302
# Постановление, региональный уровень, органы исполнительной власти       0.95      0.86      0.90       244
#                Постановление, региональный уровень, правительство       0.59      0.56      0.58       318
#                 Постановление, федеральный уровень, правительство       0.76      0.75      0.76       314
#        Приказ, региональный уровень, органы исполнительной власти       0.61      0.75      0.68       325
#         Приказ, федеральный уровень, органы исполнительной власти       0.57      0.82      0.67       315
#   Распоряжение, региональный уровень, глава исполнительной власти       0.70      0.64      0.67       330
#                 Распоряжение, региональный уровень, правительство       0.66      0.57      0.61       323
#    Распоряжение, федеральный уровень, глава исполнительной власти       0.78      0.76      0.77       272
#                  Распоряжение, федеральный уровень, правительство       0.72      0.73      0.73       324
#           Указ, региональный уровень, глава исполнительной власти       0.56      0.51      0.53       296
#            Указ, федеральный уровень, глава исполнительной власти       0.95      0.67      0.79       222
#
#                                                          accuracy                           0.71      4579
#                                                         macro avg       0.73      0.71      0.71      4579
#                                                      weighted avg       0.72      0.71      0.71      4579
#
# 0.7099803450535052 accuracy
# 0.7264905766315585 precision
# 0.7099888967628675 recall
# 0.7139002044766286 f1
